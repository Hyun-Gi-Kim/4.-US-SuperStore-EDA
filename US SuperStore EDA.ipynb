# %% [markdown]
# # Superstore data
# ### data from:  https://www.kaggle.com/rohitsahoo/sales-forecasting
# ### Retail dataset of a US superstore for 4 years
#
# ## 1. Look around the data

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn")
sns.set(font_scale=1)

import warnings
warnings.simplefilter(action = 'ignore', category=FutureWarning)

# %%
sp = pd.read_csv('Superstore Data.csv')
sp.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
sp.columns.transpose()
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
sp.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
sp.describe(include = object)
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994        9994        9994            9994        9994
# unique            5009        1237        1334               4         793
# top     CA-2017-100111  2016-09-05  2015-12-16  Standard Class    WB-21850
# freq                14          38          35            5968          37
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#        Region       Product ID         Category Sub-Category     Product Name
# count    9994             9994             9994         9994             9994
# unique      4             1862                3           17             1850
# top      West  OFF-PA-10001970  Office Supplies      Binders  Staple envelope
# freq     3203               19             6026         1523               48

# %%
print("The total number of data: ", sp.shape[0]*sp.shape[1])
print("The total number of null values: {} and it occupies {:.2f}% of the total ".format(sp.isnull().sum().sum(), (sp.isnull().sum().sum()*100)/(sp.shape[0]*sp.shape[1])))
print("Data period: {} ~ {} ".format(min(sp['Order Date']), max(sp['Order Date'])))
print("The total number of items sold: ", sp['Product ID'].nunique())
# Out:
# The total number of data:  209874
# The total number of null values: 0 and it occupies 0.00% of the total
# Data period: 2014-01-03 ~ 2017-12-30
# The total number of items sold:  1862

# %% [markdown]
# ## 2.Questions
# ### *What kind of items(sub-category) sold the most?
# ### *Which city had the highest order volume?
# ### *The order amounts and sales amounts by 'segment' ,' region'?
# ### *Does the higher the discount rate, the lower the margin?
# ### *What kind of items was recorded the highest sales?
# ### *Can I show the sales amount on the map?(Visualization)

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### 3-1. preprocess the duplicated columns.

# %%
sp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3-1. Rename the columns.

# %%
sp.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sp.columns = ['row_id','order_id','order_date','ship_date','ship_mode','cust_id','cust_name','seg'
,'country','city','state','post_code','region','product_id','category','subcategory','product_name'
,'sales','quantity','discount','profit']

# %%
sp.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode', 'cust_id',
#        'cust_name', 'seg', 'country', 'city', 'state', 'post_code', 'region',
#        'product_id', 'category', 'subcategory', 'product_name', 'sales',
#        'quantity', 'discount', 'profit'],
#       dtype='object')

# %% [markdown]
# ### 3-3. Remove unnecessary columns.

# %%
sp = sp.drop(['post_code'], axis=1)
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   row_id        9994 non-null   int64
#  1   order_id      9994 non-null   object
#  2   order_date    9994 non-null   object
#  3   ship_date     9994 non-null   object
#  4   ship_mode     9994 non-null   object
#  5   cust_id       9994 non-null   object
#  6   cust_name     9994 non-null   object
#  7   seg           9994 non-null   object
#  8   country       9994 non-null   object
#  9   city          9994 non-null   object
#  10  state         9994 non-null   object
#  11  region        9994 non-null   object
#  12  product_id    9994 non-null   object
#  13  category      9994 non-null   object
#  14  subcategory   9994 non-null   object
#  15  product_name  9994 non-null   object
#  16  sales         9994 non-null   float64
#  17  quantity      9994 non-null   int64
#  18  discount      9994 non-null   float64
#  19  profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(15)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 4.EDA & Visualization

# %%
#Top 10 items
sp['product_name'].value_counts().head(10)
# Out:
# Staple envelope                                              48
# Staples                                                      46
# Easy-staple paper                                            46
# Avery Non-Stick Binders                                      20
# Staples in misc. colors                                      19
# Staple remover                                               18
# KI Adjustable-Height Table                                   18
# Storex Dura Pro Binders                                      17
# Staple-based wall hangings                                   16
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling    15
# Name: product_name, dtype: int64

# %%
#violin plot >> check the 'sales' by category and 'discount'
f, ax = plt.subplots(1,2, figsize=(13,7))

sns.violinplot(x=sp['category'], y=sp['sales'],ax=ax[0])
sns.violinplot(x=sp['category'], y=sp['discount']*100, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='category', ylabel='discount'>

# %%
# Which items sold the most by sub-category? ratio?
#pie-graph
plt.figure(figsize=(12,10))
sp['subcategory'].value_counts().plot.pie(autopct= "%1.1f%%")

plt.show()

# %% [markdown]
# ### 4-2.Check the top 10 cities

# %%
Top_cities = sp['city'].value_counts().nlargest(20)
Top_cities
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Dallas           157
# Jacksonville     125
# Detroit          115
# Newark            95
# Richmond          90
# Jackson           82
# Columbia          81
# Aurora            68
# Phoenix           63
# Long Beach        61
# Name: city, dtype: int64

# %%
# Visualize the order amounts by states
f, ax = plt.subplots(1,1, figsize=(18,8))

g = sns.countplot(sp['state'].sort_values(), ax=ax)
g.set_title('State', size=15)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set_ylabel('')

plt.show()

# %% [markdown]
# ### 4-3.The order amounts by 'segment' and 'region'

# %%
# consumer, west
f, ax = plt.subplots(1,2, figsize=(15,6))

sns.countplot(x = sp['seg'], palette = 'magma', ax=ax[0])
ax[0].set_title('Segment')

sns.countplot(x = sp['region'], palette = 'magma', ax=ax[1])
ax[1].set_title('Region')
ax[1].set_ylabel('')

plt.show()

# %% [markdown]
# ### 4-4. Margins depending on the discount rate.

# %%
## sns.lineplot shows 'Confidence Interval' and regression line.
## The area means 'Confidence Interval'.
## estimator = None >> various x values
f, ax = plt.subplots(1,1, figsize=(18,10))

sns.lineplot('discount', 'profit', data = sp, color = 'r', ax=ax)
ax.set_xlabel("Discount(%)")
ax.set_ylabel("Profit($)")

plt.show()

# %% [markdown]
# ### 4-5. Correlation with Heatmap.

# %%
#Continuous Variables only
sp_corr = sp[['sales', 'quantity', 'discount', 'profit']].corr()
sp_corr
# Out:
#              sales  quantity  discount    profit
# sales     1.000000  0.200795 -0.028190  0.479064
# quantity  0.200795  1.000000  0.008623  0.066253
# discount -0.028190  0.008623  1.000000 -0.219487
# profit    0.479064  0.066253 -0.219487  1.000000

# %%
f, ax = plt.subplots(1,1, figsize=(9,8))

sns.heatmap(data = sp_corr, annot=True, cmap='YlGnBu', ax=ax)
ax.set_title("Correlation", size=15)
#insights: discount higher >> margin(profit) lower
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# ### 4-6.Top10 items by sales amount

# %%
top_prd1 = sp.groupby(['product_name']).sum().sort_values('sales', ascending=False).head(10)
top_prd1
# Out:
#                                                     row_id      sales  \
# product_name
# Canon imageCLASS 2200 Advanced Copier                28222  61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...   61859  27453.384
# Cisco TelePresence System EX90 Videoconferencin...    2698  22638.480
# HON 5400 Series Task Chairs for Big and Tall         44560  21870.576
# GBC DocuBind TL300 Electric Binding System           64915  19823.479
# GBC Ibimaster 500 Manual ProClick Binding System     57937  19024.500
# Hewlett Packard LaserJet 3310 Copier                 41444  18839.686
# HP Designjet T520 Inkjet Large Format Printer -...   19245  18374.895
# GBC DocuBind P400 Electric Binding System            27597  17965.068
# High Speed Automatic Electric Letter Opener          13590  17030.312
#
#                                                     quantity  discount  \
# product_name
# Canon imageCLASS 2200 Advanced Copier                     20       0.6
# Fellowes PB500 Electric Punch Plastic Comb Bind...        31       2.4
# Cisco TelePresence System EX90 Videoconferencin...         6       0.5
# HON 5400 Series Task Chairs for Big and Tall              39       1.6
# GBC DocuBind TL300 Electric Binding System                37       3.3
# GBC Ibimaster 500 Manual ProClick Binding System          48       4.7
# Hewlett Packard LaserJet 3310 Copier                      38       1.6
# HP Designjet T520 Inkjet Large Format Printer -...        12       0.5
# GBC DocuBind P400 Electric Binding System                 27       2.7
# High Speed Automatic Electric Letter Opener               11       0.2
#
#                                                           profit
# product_name
# Canon imageCLASS 2200 Advanced Copier               2.519993e+04
# Fellowes PB500 Electric Punch Plastic Comb Bind...  7.753039e+03
# Cisco TelePresence System EX90 Videoconferencin... -1.811078e+03
# HON 5400 Series Task Chairs for Big and Tall        5.684342e-14
# GBC DocuBind TL300 Electric Binding System          2.233505e+03
# GBC Ibimaster 500 Manual ProClick Binding System    7.609800e+02
# Hewlett Packard LaserJet 3310 Copier                6.983884e+03
# HP Designjet T520 Inkjet Large Format Printer -...  4.094977e+03
# GBC DocuBind P400 Electric Binding System          -1.878166e+03
# High Speed Automatic Electric Letter Opener        -2.620048e+02

# %%
top_prd1.reset_index(inplace=True)
top_prd1
# Out:
#                                         product_name  row_id      sales  \
# 0              Canon imageCLASS 2200 Advanced Copier   28222  61599.824
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...   61859  27453.384
# 2  Cisco TelePresence System EX90 Videoconferenci...    2698  22638.480
# 3       HON 5400 Series Task Chairs for Big and Tall   44560  21870.576
# 4         GBC DocuBind TL300 Electric Binding System   64915  19823.479
# 5   GBC Ibimaster 500 Manual ProClick Binding System   57937  19024.500
# 6               Hewlett Packard LaserJet 3310 Copier   41444  18839.686
# 7  HP Designjet T520 Inkjet Large Format Printer ...   19245  18374.895
# 8          GBC DocuBind P400 Electric Binding System   27597  17965.068
# 9        High Speed Automatic Electric Letter Opener   13590  17030.312
#
#    quantity  discount        profit
# 0        20       0.6  2.519993e+04
# 1        31       2.4  7.753039e+03
# 2         6       0.5 -1.811078e+03
# 3        39       1.6  5.684342e-14
# 4        37       3.3  2.233505e+03
# 5        48       4.7  7.609800e+02
# 6        38       1.6  6.983884e+03
# 7        12       0.5  4.094977e+03
# 8        27       2.7 -1.878166e+03
# 9        11       0.2 -2.620048e+02

# %%
f, ax = plt.subplots(1,1, figsize=(9,8))

ax.pie(top_prd1['sales'], labels = top_prd1['product_name'], autopct="%1.1f%%",
      startangle=0)
ax.set_ylabel('')

center_circle = plt.Circle((0,0), 0.5, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)

ax.axis('equal')
label = ax.annotate("Top 10 items\n by Sales amount", color='black', xy=(0,-0.07), fontsize=15, ha="center")

plt.show()

# %% [markdown]
# ### 4-7. The total sales amouts by states on the map.

# %%
sales = sp.groupby(['state']).sum().sort_values('sales', ascending = False)
sales.reset_index(level=0, inplace = True)
#sales = sales.sort_values('state', ascending = True)
sales
# Out:
#                    state    row_id        sales  quantity  discount  \
# 0             California  10137449  457687.6315      7667    145.60
# 1               New York   5452096  310876.2710      4224     62.40
# 2                  Texas   5085541  170188.0458      3724    364.64
# 3             Washington   2584458  138641.2700      1883     32.40
# 4           Pennsylvania   2768523  116511.9140      2153    192.90
# 5                Florida   1958255   89473.7080      1379    114.65
# 6               Illinois   2571481   80166.1010      1845    191.90
# 7                   Ohio   2355994   78258.1360      1759    152.40
# 8               Michigan   1200167   76269.6140       946      1.80
# 9               Virginia   1218137   70636.7200       893      0.00
# 10        North Carolina   1219177   55603.1640       983     70.60
# 11               Indiana    728770   53555.3600       578      0.00
# 12               Georgia    883590   49095.8400       705      0.00
# 13              Kentucky    698921   36591.7500       523      0.00
# 14            New Jersey    653855   35764.3120       454      0.60
# 15               Arizona   1019876   35282.0010       862     68.00
# 16             Wisconsin    570981   32114.6100       463      0.00
# 17              Colorado    797002   32108.1180       693     57.60
# 18             Tennessee   1068141   30661.8730       681     53.30
# 19             Minnesota    316645   29863.1500       331      0.00
# 20         Massachusetts    708877   28634.4340       491      2.10
# 21              Delaware    504370   27451.0690       367      0.60
# 22              Maryland    556423   23705.5230       420      0.60
# 23          Rhode Island    305385   22627.9560       199      1.20
# 24              Missouri    325246   22205.1500       252      0.00
# 25              Oklahoma    328549   19683.3900       247      0.00
# 26               Alabama    243876   19510.6400       256      0.00
# 27                Oregon    652996   17431.1500       499     35.80
# 28                Nevada    223546   16729.1020       168      2.40
# 29           Connecticut    444411   13384.3570       281      0.60
# 30              Arkansas    304575   11678.1300       240      0.00
# 31                  Utah    193525   11220.0560       219      3.20
# 32           Mississippi    250903   10771.3400       221      0.00
# 33             Louisiana    173625    9217.0300       156      0.00
# 34               Vermont     91049    8929.3700        50      0.00
# 35        South Carolina    194095    8481.7100       172      0.00
# 36              Nebraska    205384    7464.9300       136      0.00
# 37         New Hampshire    135645    7292.5240       127      0.30
# 38               Montana     61438    5589.3520        56      1.00
# 39            New Mexico    166251    4783.5220       151      2.20
# 40                  Iowa    142173    4579.7600       112      0.00
# 41                 Idaho    129427    4382.4860        64      1.80
# 42                Kansas    125372    2914.3100        74      0.00
# 43  District of Columbia     17918    2865.0200        40      0.00
# 44               Wyoming      5870    1603.1360         4      0.20
# 45          South Dakota     48858    1315.5600        42      0.00
# 46                 Maine     46198    1270.5300        35      0.00
# 47         West Virginia     33175    1209.8240        18      0.30
# 48          North Dakota     36796     919.9100        30      0.00
#
#         profit
# 0   76381.3871
# 1   74038.5486
# 2  -25729.3563
# 3   33402.6517
# 4  -15559.9603
# 5   -3399.3017
# 6  -12607.8870
# 7  -16971.3766
# 8   24463.1876
# 9   18597.9504
# 10  -7490.9122
# 11  18382.9363
# 12  16250.0433
# 13  11199.6966
# 14   9772.9138
# 15  -3427.9246
# 16   8401.8004
# 17  -6527.8579
# 18  -5341.6936
# 19  10823.1874
# 20   6785.5016
# 21   9977.3748
# 22   7031.1788
# 23   7285.6293
# 24   6436.2105
# 25   4853.9560
# 26   5786.8253
# 27  -1190.4705
# 28   3316.7659
# 29   3511.4918
# 30   4008.6871
# 31   2546.5335
# 32   3172.9762
# 33   2196.1023
# 34   2244.9783
# 35   1769.0566
# 36   2037.0942
# 37   1706.5028
# 38   1833.3285
# 39   1157.1161
# 40   1183.8119
# 41    826.7231
# 42    836.4435
# 43   1059.5893
# 44    100.1960
# 45    394.8283
# 46    454.4862
# 47    185.9216
# 48    230.1497

# %%
# Technically, DC is not the state. Let's remove it!
dc = sales[sales['state'] == 'District of Columbia'].index
sales = sales.drop(dc)
sales
# Out:
#              state    row_id        sales  quantity  discount      profit
# 0       California  10137449  457687.6315      7667    145.60  76381.3871
# 1         New York   5452096  310876.2710      4224     62.40  74038.5486
# 2            Texas   5085541  170188.0458      3724    364.64 -25729.3563
# 3       Washington   2584458  138641.2700      1883     32.40  33402.6517
# 4     Pennsylvania   2768523  116511.9140      2153    192.90 -15559.9603
# 5          Florida   1958255   89473.7080      1379    114.65  -3399.3017
# 6         Illinois   2571481   80166.1010      1845    191.90 -12607.8870
# 7             Ohio   2355994   78258.1360      1759    152.40 -16971.3766
# 8         Michigan   1200167   76269.6140       946      1.80  24463.1876
# 9         Virginia   1218137   70636.7200       893      0.00  18597.9504
# 10  North Carolina   1219177   55603.1640       983     70.60  -7490.9122
# 11         Indiana    728770   53555.3600       578      0.00  18382.9363
# 12         Georgia    883590   49095.8400       705      0.00  16250.0433
# 13        Kentucky    698921   36591.7500       523      0.00  11199.6966
# 14      New Jersey    653855   35764.3120       454      0.60   9772.9138
# 15         Arizona   1019876   35282.0010       862     68.00  -3427.9246
# 16       Wisconsin    570981   32114.6100       463      0.00   8401.8004
# 17        Colorado    797002   32108.1180       693     57.60  -6527.8579
# 18       Tennessee   1068141   30661.8730       681     53.30  -5341.6936
# 19       Minnesota    316645   29863.1500       331      0.00  10823.1874
# 20   Massachusetts    708877   28634.4340       491      2.10   6785.5016
# 21        Delaware    504370   27451.0690       367      0.60   9977.3748
# 22        Maryland    556423   23705.5230       420      0.60   7031.1788
# 23    Rhode Island    305385   22627.9560       199      1.20   7285.6293
# 24        Missouri    325246   22205.1500       252      0.00   6436.2105
# 25        Oklahoma    328549   19683.3900       247      0.00   4853.9560
# 26         Alabama    243876   19510.6400       256      0.00   5786.8253
# 27          Oregon    652996   17431.1500       499     35.80  -1190.4705
# 28          Nevada    223546   16729.1020       168      2.40   3316.7659
# 29     Connecticut    444411   13384.3570       281      0.60   3511.4918
# 30        Arkansas    304575   11678.1300       240      0.00   4008.6871
# 31            Utah    193525   11220.0560       219      3.20   2546.5335
# 32     Mississippi    250903   10771.3400       221      0.00   3172.9762
# 33       Louisiana    173625    9217.0300       156      0.00   2196.1023
# 34         Vermont     91049    8929.3700        50      0.00   2244.9783
# 35  South Carolina    194095    8481.7100       172      0.00   1769.0566
# 36        Nebraska    205384    7464.9300       136      0.00   2037.0942
# 37   New Hampshire    135645    7292.5240       127      0.30   1706.5028
# 38         Montana     61438    5589.3520        56      1.00   1833.3285
# 39      New Mexico    166251    4783.5220       151      2.20   1157.1161
# 40            Iowa    142173    4579.7600       112      0.00   1183.8119
# 41           Idaho    129427    4382.4860        64      1.80    826.7231
# 42          Kansas    125372    2914.3100        74      0.00    836.4435
# 44         Wyoming      5870    1603.1360         4      0.20    100.1960
# 45    South Dakota     48858    1315.5600        42      0.00    394.8283
# 46           Maine     46198    1270.5300        35      0.00    454.4862
# 47   West Virginia     33175    1209.8240        18      0.30    185.9216
# 48    North Dakota     36796     919.9100        30      0.00    230.1497

# %%
# Add the state_code for the graph.
state = ['Alabama', 'Arizona' ,'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 
         'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
         'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana','Nebraska', 'Nevada', 'New Hampshire',
         'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
         'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
         'West Virginia', 'Wisconsin','Wyoming']
state_code = ['AL','AZ','AR','CA','CO','CT','DE','FL','GA','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA',
              'MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN',
              'TX','UT','VT','VA','WA','WV','WI','WY']

# Merge the 'state_code' with 'state'
state_cd = pd.DataFrame(state, state_code)
state_cd
state_cd.reset_index(inplace = True)
state_cd.columns = ['state_cd', 'state']
state_cd
# Out:
#    state_cd           state
# 0        AL         Alabama
# 1        AZ         Arizona
# 2        AR        Arkansas
# 3        CA      California
# 4        CO        Colorado
# 5        CT     Connecticut
# 6        DE        Delaware
# 7        FL         Florida
# 8        GA         Georgia
# 9        ID           Idaho
# 10       IL        Illinois
# 11       IN         Indiana
# 12       IA            Iowa
# 13       KS          Kansas
# 14       KY        Kentucky
# 15       LA       Louisiana
# 16       ME           Maine
# 17       MD        Maryland
# 18       MA   Massachusetts
# 19       MI        Michigan
# 20       MN       Minnesota
# 21       MS     Mississippi
# 22       MO        Missouri
# 23       MT         Montana
# 24       NE        Nebraska
# 25       NV          Nevada
# 26       NH   New Hampshire
# 27       NJ      New Jersey
# 28       NM      New Mexico
# 29       NY        New York
# 30       NC  North Carolina
# 31       ND    North Dakota
# 32       OH            Ohio
# 33       OK        Oklahoma
# 34       OR          Oregon
# 35       PA    Pennsylvania
# 36       RI    Rhode Island
# 37       SC  South Carolina
# 38       SD    South Dakota
# 39       TN       Tennessee
# 40       TX           Texas
# 41       UT            Utah
# 42       VT         Vermont
# 43       VA        Virginia
# 44       WA      Washington
# 45       WV   West Virginia
# 46       WI       Wisconsin
# 47       WY         Wyoming

# %%
# Arrange the dataset by 'state' in order to add 'state_cd' column.
sales = sales.sort_values('state', ascending = True)
sales.reset_index(inplace = True)
sales.insert(1, 'state_cd', state_cd['state_cd'])
sales
# Out:
#     index state_cd           state    row_id        sales  quantity  discount  \
# 0      26       AL         Alabama    243876   19510.6400       256      0.00
# 1      15       AZ         Arizona   1019876   35282.0010       862     68.00
# 2      30       AR        Arkansas    304575   11678.1300       240      0.00
# 3       0       CA      California  10137449  457687.6315      7667    145.60
# 4      17       CO        Colorado    797002   32108.1180       693     57.60
# 5      29       CT     Connecticut    444411   13384.3570       281      0.60
# 6      21       DE        Delaware    504370   27451.0690       367      0.60
# 7       5       FL         Florida   1958255   89473.7080      1379    114.65
# 8      12       GA         Georgia    883590   49095.8400       705      0.00
# 9      41       ID           Idaho    129427    4382.4860        64      1.80
# 10      6       IL        Illinois   2571481   80166.1010      1845    191.90
# 11     11       IN         Indiana    728770   53555.3600       578      0.00
# 12     40       IA            Iowa    142173    4579.7600       112      0.00
# 13     42       KS          Kansas    125372    2914.3100        74      0.00
# 14     13       KY        Kentucky    698921   36591.7500       523      0.00
# 15     33       LA       Louisiana    173625    9217.0300       156      0.00
# 16     46       ME           Maine     46198    1270.5300        35      0.00
# 17     22       MD        Maryland    556423   23705.5230       420      0.60
# 18     20       MA   Massachusetts    708877   28634.4340       491      2.10
# 19      8       MI        Michigan   1200167   76269.6140       946      1.80
# 20     19       MN       Minnesota    316645   29863.1500       331      0.00
# 21     32       MS     Mississippi    250903   10771.3400       221      0.00
# 22     24       MO        Missouri    325246   22205.1500       252      0.00
# 23     38       MT         Montana     61438    5589.3520        56      1.00
# 24     36       NE        Nebraska    205384    7464.9300       136      0.00
# 25     28       NV          Nevada    223546   16729.1020       168      2.40
# 26     37       NH   New Hampshire    135645    7292.5240       127      0.30
# 27     14       NJ      New Jersey    653855   35764.3120       454      0.60
# 28     39       NM      New Mexico    166251    4783.5220       151      2.20
# 29      1       NY        New York   5452096  310876.2710      4224     62.40
# 30     10       NC  North Carolina   1219177   55603.1640       983     70.60
# 31     48       ND    North Dakota     36796     919.9100        30      0.00
# 32      7       OH            Ohio   2355994   78258.1360      1759    152.40
# 33     25       OK        Oklahoma    328549   19683.3900       247      0.00
# 34     27       OR          Oregon    652996   17431.1500       499     35.80
# 35      4       PA    Pennsylvania   2768523  116511.9140      2153    192.90
# 36     23       RI    Rhode Island    305385   22627.9560       199      1.20
# 37     35       SC  South Carolina    194095    8481.7100       172      0.00
# 38     45       SD    South Dakota     48858    1315.5600        42      0.00
# 39     18       TN       Tennessee   1068141   30661.8730       681     53.30
# 40      2       TX           Texas   5085541  170188.0458      3724    364.64
# 41     31       UT            Utah    193525   11220.0560       219      3.20
# 42     34       VT         Vermont     91049    8929.3700        50      0.00
# 43      9       VA        Virginia   1218137   70636.7200       893      0.00
# 44      3       WA      Washington   2584458  138641.2700      1883     32.40
# 45     47       WV   West Virginia     33175    1209.8240        18      0.30
# 46     16       WI       Wisconsin    570981   32114.6100       463      0.00
# 47     44       WY         Wyoming      5870    1603.1360         4      0.20
#
#         profit
# 0    5786.8253
# 1   -3427.9246
# 2    4008.6871
# 3   76381.3871
# 4   -6527.8579
# 5    3511.4918
# 6    9977.3748
# 7   -3399.3017
# 8   16250.0433
# 9     826.7231
# 10 -12607.8870
# 11  18382.9363
# 12   1183.8119
# 13    836.4435
# 14  11199.6966
# 15   2196.1023
# 16    454.4862
# 17   7031.1788
# 18   6785.5016
# 19  24463.1876
# 20  10823.1874
# 21   3172.9762
# 22   6436.2105
# 23   1833.3285
# 24   2037.0942
# 25   3316.7659
# 26   1706.5028
# 27   9772.9138
# 28   1157.1161
# 29  74038.5486
# 30  -7490.9122
# 31    230.1497
# 32 -16971.3766
# 33   4853.9560
# 34  -1190.4705
# 35 -15559.9603
# 36   7285.6293
# 37   1769.0566
# 38    394.8283
# 39  -5341.6936
# 40 -25729.3563
# 41   2546.5335
# 42   2244.9783
# 43  18597.9504
# 44  33402.6517
# 45    185.9216
# 46   8401.8004
# 47    100.1960

# %%
sales.drop('index',1,inplace = True)
sales
# Out:
#    state_cd           state    row_id        sales  quantity  discount  \
# 0        AL         Alabama    243876   19510.6400       256      0.00
# 1        AZ         Arizona   1019876   35282.0010       862     68.00
# 2        AR        Arkansas    304575   11678.1300       240      0.00
# 3        CA      California  10137449  457687.6315      7667    145.60
# 4        CO        Colorado    797002   32108.1180       693     57.60
# 5        CT     Connecticut    444411   13384.3570       281      0.60
# 6        DE        Delaware    504370   27451.0690       367      0.60
# 7        FL         Florida   1958255   89473.7080      1379    114.65
# 8        GA         Georgia    883590   49095.8400       705      0.00
# 9        ID           Idaho    129427    4382.4860        64      1.80
# 10       IL        Illinois   2571481   80166.1010      1845    191.90
# 11       IN         Indiana    728770   53555.3600       578      0.00
# 12       IA            Iowa    142173    4579.7600       112      0.00
# 13       KS          Kansas    125372    2914.3100        74      0.00
# 14       KY        Kentucky    698921   36591.7500       523      0.00
# 15       LA       Louisiana    173625    9217.0300       156      0.00
# 16       ME           Maine     46198    1270.5300        35      0.00
# 17       MD        Maryland    556423   23705.5230       420      0.60
# 18       MA   Massachusetts    708877   28634.4340       491      2.10
# 19       MI        Michigan   1200167   76269.6140       946      1.80
# 20       MN       Minnesota    316645   29863.1500       331      0.00
# 21       MS     Mississippi    250903   10771.3400       221      0.00
# 22       MO        Missouri    325246   22205.1500       252      0.00
# 23       MT         Montana     61438    5589.3520        56      1.00
# 24       NE        Nebraska    205384    7464.9300       136      0.00
# 25       NV          Nevada    223546   16729.1020       168      2.40
# 26       NH   New Hampshire    135645    7292.5240       127      0.30
# 27       NJ      New Jersey    653855   35764.3120       454      0.60
# 28       NM      New Mexico    166251    4783.5220       151      2.20
# 29       NY        New York   5452096  310876.2710      4224     62.40
# 30       NC  North Carolina   1219177   55603.1640       983     70.60
# 31       ND    North Dakota     36796     919.9100        30      0.00
# 32       OH            Ohio   2355994   78258.1360      1759    152.40
# 33       OK        Oklahoma    328549   19683.3900       247      0.00
# 34       OR          Oregon    652996   17431.1500       499     35.80
# 35       PA    Pennsylvania   2768523  116511.9140      2153    192.90
# 36       RI    Rhode Island    305385   22627.9560       199      1.20
# 37       SC  South Carolina    194095    8481.7100       172      0.00
# 38       SD    South Dakota     48858    1315.5600        42      0.00
# 39       TN       Tennessee   1068141   30661.8730       681     53.30
# 40       TX           Texas   5085541  170188.0458      3724    364.64
# 41       UT            Utah    193525   11220.0560       219      3.20
# 42       VT         Vermont     91049    8929.3700        50      0.00
# 43       VA        Virginia   1218137   70636.7200       893      0.00
# 44       WA      Washington   2584458  138641.2700      1883     32.40
# 45       WV   West Virginia     33175    1209.8240        18      0.30
# 46       WI       Wisconsin    570981   32114.6100       463      0.00
# 47       WY         Wyoming      5870    1603.1360         4      0.20
#
#         profit
# 0    5786.8253
# 1   -3427.9246
# 2    4008.6871
# 3   76381.3871
# 4   -6527.8579
# 5    3511.4918
# 6    9977.3748
# 7   -3399.3017
# 8   16250.0433
# 9     826.7231
# 10 -12607.8870
# 11  18382.9363
# 12   1183.8119
# 13    836.4435
# 14  11199.6966
# 15   2196.1023
# 16    454.4862
# 17   7031.1788
# 18   6785.5016
# 19  24463.1876
# 20  10823.1874
# 21   3172.9762
# 22   6436.2105
# 23   1833.3285
# 24   2037.0942
# 25   3316.7659
# 26   1706.5028
# 27   9772.9138
# 28   1157.1161
# 29  74038.5486
# 30  -7490.9122
# 31    230.1497
# 32 -16971.3766
# 33   4853.9560
# 34  -1190.4705
# 35 -15559.9603
# 36   7285.6293
# 37   1769.0566
# 38    394.8283
# 39  -5341.6936
# 40 -25729.3563
# 41   2546.5335
# 42   2244.9783
# 43  18597.9504
# 44  33402.6517
# 45    185.9216
# 46   8401.8004
# 47    100.1960

# %%
# Use plotly to show a responsive graph.
import plotly.express as px

fig = px.choropleth(locations = sales['state_cd'], locationmode="USA-states", color = sales['sales'], scope="usa",
                   color_continuous_scale='peach', title = "The total sales amounts by the states")

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 # Use plotly to show a responsive graph.
#       2 import plotly.express as px
# ----> 4 fig = px.choropleth(locations = sales['state_cd'], locationmode="USA-states", color = sales['sales'], scope="usa",
#       5                    color_continuous_scale='peach', title = "The total sales amounts by the states")
#       7 fig.show()
#
# NameError: name 'sales' is not defined

# %% [markdown]
# ## 5.Review
#
# ### The total number of data:  209874
# ### The total number of null values: 0 and it occupies 0.00% of the total
# ### Data period:    2014-01-03 ~ 2017-12-30
# ### The total number of items sold:  1862
#
# ### Q: Which items sold the most by sub-category? ratio?
# #### A: Binders, 15.2%
#
# ### Q: Which city had the highest order volume?
# #### A: 1. CA, 2. NY, 3. TX
#
# ### Q: The order amounts by 'segment' and 'region'?
# #### A: The consumer seg was recorded the highest and the West had the most order volume.
#
# ### Q: Does the higher the discout rate, the lower the profit?
# #### A: When the discount rate was 50%, the profit was the shortest.
#
# ### Q: What kind of items was recorded the highest sales?
# #### A: The sales of Canon imageCLASS 2200 Advanced Copier was the highest.
#
# ### Q: Can I show sales on the map?
# #### A: Yes, I made it!
